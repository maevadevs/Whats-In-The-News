# %% [markdown]
# # Mapping Sections To Categories

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Generalizing-the-Categories" data-toc-modified-id="Generalizing-the-Categories-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Generalizing the Categories</a></span></li></ul></div>

# %%
from sqlalchemy import create_engine   # conda install -c anaconda sqlalchemy
from dotenv import load_dotenv         # conda install -c conda-forge python-dotenv
import os                              # Python default package
import pandas as pd

# For visualizations
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
sns.set_theme(style="whitegrid")

# %%
pd.options.display.max_rows = 1000
pd.set_option('max_colwidth', 400)

# %%
load_dotenv() # => True if no error
# Out:
# True

# %%
# Load secrets from the .env file
db_name = os.getenv("db_name")
db_username = os.getenv("db_username")
db_password = os.getenv("db_password")
db_table_schema = os.getenv("db_table_schema")
connection_string = f"postgres://{db_username}:{db_password}@localhost:5432/{db_name}"
engine = create_engine(connection_string)

# %%
# List of available tables in the DB
q = """
SELECT * 
FROM information_schema.tables
WHERE table_catalog = '{db_name}'
AND table_schema = '{db_table_schema}';
""".format(
    db_name = db_name,
    db_table_schema = db_table_schema
)

pd.read_sql(q, con=engine)[["table_name"]]
# Out:
#           table_name
# 0       AllTheNews21
# 1        BBCArticles
# 2  BBCSportsArticles

# %% [markdown]
# ## Generalizing the Categories

# %% [markdown]
# We are generalizing the categories in the following manner:
#
# [TBD -- Check ongoing work in #07]

# %%
q = """
SELECT DISTINCT section
FROM public."AllTheNews21"
WHERE year 
"""
pd.read_sql(q, con=engine)
# Out:
#                                         section
# 0                                          None
# 1                          London Market Report
# 2                       Consumer Goods & Retail
# 3                                   Expert Zone
# 4                                    Bonds News
# 5                       Hong Kong Market Report
# 6                                      Colombia
# 7                             Fishing & Farming
# 8                                   North Korea
# 9                                      AlertNet
# 10                                         U.S.
# 11                                    Data Dive
# 12                                 Big Story 10
# 13               Appliances, Tools & Housewares
# 14                                         Arts
# 15                               Deals - Europe
# 16                                     News Now
# 17                       Hedge Funds - Americas
# 18                                          G20
# 19                        US College Basketball
# 20                    China Party Congress 2017
# 21                                  Target LGBT
# 22                   Retail - Department Stores
# 23                                        blank
# 24               Global Investment Outlook 2020
# 25                              Bankruptcy News
# 26                                 Olympics Rio
# 27                            Money Markets RSS
# 28                            Computer Hardware
# 29                                   Regulation
# 30                                    Film News
# 31                            SPONSORED CONTENT
# 32                                  Euro Crisis
# 33                                Internet News
# 34                                       Russia
# 35                            Reuters Backstory
# 36                              Derivatives RSS
# 37                                         Asia
# 38                                    bjdevtest
# 39                          Aerospace & Defense
# 40                          Investment Services
# 41                          Hedge Funds - Asias
# 42                                       Wealth
# 43                                   World News
# 44            Mergers & Acquisitions - Americas
# 45                                    Apple Inc
# 46                        Hedge Funds - Europes
# 47                                   Cyber Risk
# 48                                    Sports WC
# 49                     Textiles & Leather Goods
# 50                           Sponsored Content
# 51                     Communications Equipment
# 52                                   Technology
# 53                                        Intel
# 54                                 Oddly Enough
# 55                    Switzerland Market Report
# 56         Innovation and Intellectual Property
# 57                                   Media News
# 58                                 Broadcasting
# 59                              Television News
# 60                                        Banks
# 61                                          RPB
# 62                                  Commodities
# 63                             Leisure Products
# 64                           Retail - Specialty
# 65                         Sustainable Business
# 66                                 Trump Effect
# 67                            Sponsored Content
# 68                                Breakingviews
# 69                               India Top News
# 70                              Earnings Season
# 71                           Caroline Wozniacki
# 72                           Reuters Fact Check
# 73                             Corrections News
# 74       Food Distribution & Convenience Stores
# 75                    Consumer Goods and Retail
# 76                           Entertainment News
# 77                                      Factbox
# 78                                   Faithworld
# 79                                Supreme Court
# 80                                  Restaurants
# 81                           Internet of Things
# 82               Global Investment 2018 Outlook
# 83                                 Big Story 12
# 84                                     Airlines
# 85                           Gold Market Report
# 86                                  Health News
