# %% [markdown]
# # Testing Pegasus Summarization on BBC Sports

# %% [markdown]
# ## About PEGASUS

# %% [markdown]
# In the last week of December 2019, Google Brain team launched this state of the art summarization model PEGASUS, which expands to Pre-training with Extracted Gap-sentences for Abstractive Summarization. Here, we will just be looking at how we can generate summaries using the pre-trained model.
#
# Let’s see how we can use the given pre-trained model to generate summaries for our text.

# %% [markdown]
# **Reference Used**
#
# - https://signal.onepointltd.com/post/102ghb9/exploring-pegasus-a-new-text-summarization-nlp-model**
# - https://huggingface.co/transformers/model_doc/pegasus.html#usage-example
# - https://github.com/google-research/pegasus

# %% [markdown]
# ## Import Libraries and Settings

# %%
# !pip install transformers==4.2.0
# Out:
# Collecting transformers==4.2.0
#   Downloading transformers-4.2.0-py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 18.8 MB/s
# Collecting tokenizers==0.9.4
#   Downloading tokenizers-0.9.4-cp38-cp38-manylinux2010_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 50.0 MB/s
# Requirement already satisfied: numpy in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (1.19.5)
# Requirement already satisfied: sacremoses in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (0.0.45)
# Requirement already satisfied: requests in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (2.25.1)
# Requirement already satisfied: tqdm>=4.27 in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (4.60.0)
# Requirement already satisfied: regex!=2019.12.17 in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (2021.4.4)
# Requirement already satisfied: packaging in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (20.9)
# Requirement already satisfied: filelock in /opt/python/envs/default/lib/python3.8/site-packages (from transformers==4.2.0) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/python/envs/default/lib/python3.8/site-packages (from packaging->transformers==4.2.0) (2.4.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->transformers==4.2.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->transformers==4.2.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->transformers==4.2.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/python/envs/default/lib/python3.8/site-packages (from requests->transformers==4.2.0) (1.25.11)
# Requirement already satisfied: six in /opt/python/envs/default/lib/python3.8/site-packages (from sacremoses->transformers==4.2.0) (1.15.0)
# Requirement already satisfied: click in /opt/python/envs/default/lib/python3.8/site-packages (from sacremoses->transformers==4.2.0) (7.1.2)
# Requirement already satisfied: joblib in /opt/python/envs/default/lib/python3.8/site-packages (from sacremoses->transformers==4.2.0) (1.0.1)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.10.2
#     Uninstalling tokenizers-0.10.2:
#       Successfully uninstalled tokenizers-0.10.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.3.3
#     Uninstalling transformers-4.3.3:
#       Successfully uninstalled transformers-4.3.3
# Successfully installed tokenizers-0.9.4 transformers-4.2.0
# WARNING: You are using pip version 21.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /opt/python/envs/default/lib/python3.8/site-packages (1.8.0+cpu)
# Requirement already satisfied: typing-extensions in /opt/python/envs/default/lib/python3.8/site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in /opt/python/envs/default/lib/python3.8/site-packages (from torch) (1.19.5)
# WARNING: You are using pip version 21.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.95-cp38-cp38-manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 19.7 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95
# WARNING: You are using pip version 21.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.6.2-py3-none-any.whl (2.7 MB)
#      |████████████████████████████████| 2.7 MB 17.6 MB/s
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.6.2
# WARNING: You are using pip version 21.1; however, version 21.1.2 is available.
# You should consider upgrading via the '/opt/python/envs/default/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
import io

# conda install pytorch torchvision torchaudio cudatoolkit=10.2 -c pytorch
import torch

# conda install -c conda-forge python-dotenv
# from dotenv import load_dotenv

# conda install -c anaconda sqlalchemy
# from sqlalchemy import create_engine

# conda install -c conda-forge transformers
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
from transformers import pipeline
from transformers import AutoModelWithLMHead, AutoTokenizer

# %%
# Read BBC Sports
bbc_sports = pd.read_csv("/data/workspace_files/bbc_sports.csv")
print(bbc_sports.shape)
bbc_sports.head()
# Out:
# (737, 4)
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>category</th>
#       <th>titles</th>
#       <th>contents</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>athletics</td>
#       <td>Claxton hunting first major medal</td>
#       <td>British hurdler Sarah Claxton is confident she...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>athletics</td>
#       <td>O'Sullivan could run in Worlds</td>
#       <td>Sonia O'Sullivan has indicated that she would ...</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>athletics</td>
#       <td>Greene sets sights on world title</td>
#       <td>Maurice Greene aims to wipe out the pain of lo...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>athletics</td>
#       <td>IAAF launches fight against drugs</td>
#       <td>The IAAF - athletics' world governing body - h...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>athletics</td>
#       <td>Dibaba breaks 5,000m world record</td>
#       <td>Ethiopia's Tirunesh Dibaba set a new world rec...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Abstract Summarization With Pegasus on `bbc_sports`

# %%
# Generating pegasus summary
pegasus_summaries = np.array([])

# %%
# Choosing a model: "Pegasus-XSUM"
model_name = 'google/pegasus-xsum'
model_name
# Out:
# 'google/pegasus-xsum'

# %%
# Set PyTorch
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch_device
# Out:
# 'cpu'

# %%
# Set Tokenizer based on model above
tokenizer = PegasusTokenizer.from_pretrained(model_name)
tokenizer
# Out:
# PreTrainedTokenizer(name_or_path='google/pegasus-xsum', vocab_size=96103, model_max_len=512, is_fast=False, padding_side='right', special_tokens={'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '<pad>', 'mask_token': '<mask_2>', 'additional_special_tokens': ['<mask_1>', '<unk_2>', '<unk_3>', '<unk_4>', '<unk_5>', '<unk_6>', '<unk_7>', '<unk_8>', '<unk_9>', '<unk_10>', '<unk_11>', '<unk_12>', '<unk_13>', '<unk_14>', '<unk_15>', '<unk_16>', '<unk_17>', '<unk_18>', '<unk_19>', '<unk_20>', '<unk_21>', '<unk_22>', '<unk_23>', '<unk_24>', '<unk_25>', '<unk_26>', '<unk_27>', '<unk_28>', '<unk_29>', '<unk_30>', '<unk_31>', '<unk_32>', '<unk_33>', '<unk_34>', '<unk_35>', '<unk_36>', '<unk_37>', '<unk_38>', '<unk_39>', '<unk_40>', '<unk_41>', '<unk_42>', '<unk_43>', '<unk_44>', '<unk_45>', '<unk_46>', '<unk_47>', '<unk_48>', '<unk_49>', '<unk_50>', '<unk_51>', '<unk_52>', '<unk_53>', '<unk_54>', '<unk_55>', '<unk_56>', '<unk_57>', '<unk_58>', '<unk_59>', '<unk_60>', '<unk_61>', '<unk_62>', '<unk_63>', '<unk_64>', '<unk_65>', '<unk_66>', '<unk_67>', '<unk_68>', '<unk_69>', '<unk_70>', '<unk_71>', '<unk_72>', '<unk_73>', '<unk_74>', '<unk_75>', '<unk_76>', '<unk_77>', '<unk_78>', '<unk_79>', '<unk_80>', '<unk_81>', '<unk_82>', '<unk_83>', '<unk_84>', '<unk_85>', '<unk_86>', '<unk_87>', '<unk_88>', '<unk_89>', '<unk_90>', '<unk_91>', '<unk_92>', '<unk_93>', '<unk_94>', '<unk_95>', '<unk_96>', '<unk_97>', '<unk_98>', '<unk_99>', '<unk_100>', '<unk_101>', '<unk_102>']})

# %%
# Set the Pegasus Model
# This line will run for ~60s
model = PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
model
# Out:
# PegasusForConditionalGeneration(
#   (model): PegasusModel(
#     (shared): Embedding(96103, 1024, padding_idx=0)
#     (encoder): PegasusEncoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): PegasusSinusoidalPositionalEmbedding(512, 1024)
#       (layers): ModuleList(
#         (0): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): PegasusEncoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder): PegasusDecoder(
#       (embed_tokens): Embedding(96103, 1024, padding_idx=0)
#       (embed_positions): PegasusSinusoidalPositionalEmbedding(512, 1024)
#       (layers): ModuleList(
#         (0): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (12): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (13): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (14): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#         (15): PegasusDecoderLayer(
#           (self_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (encoder_attn): PegasusAttention(
#             (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#           )
#           (encoder_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=1024, out_features=4096, bias=True)
#           (fc2): Linear(in_features=4096, out_features=1024, bias=True)
#           (final_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#       (layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (lm_head): Linear(in_features=1024, out_features=96103, bias=False)
# )

# %% [markdown]
# **NOTE: The following line will run for a long time (t=). If you need to re-generate the CSV with the summaries, re-run this line. Otherwise, it is better to skip it and simply re-import the previously-generated CSV.**

# %%
# Loop through the texts to generate the summaries
for txt in bbc_sports["contents"]:
    batch = tokenizer.prepare_seq2seq_batch(
        txt, 
        truncation=True, 
        padding='longest',
        return_tensors="pt"
    ).to(torch_device)

    tgt_text = tokenizer.batch_decode(
        model.generate(**batch), 
        skip_special_tokens=True
    )

    # Append result
    pegasus_summaries = np.append(pegasus_summaries, tgt_text[0])

    # Finally, return the short summary
    #return tgt_text[0]


# Runtime Total: BBC-Sports (25) =

# %%
# Check list of summaries
pegasus_summaries
# Out:
# array(['All images are copyrighted.', 'All images are copyrighted.',
#        '"I believe if I was in the middle of the race I would have been able to react to people that came ahead of me."',
#        "Athletics' world governing body has met anti-doping officials, coaches and athletes to co-ordinate the fight against drugs in sport. The IAAF - athletics' world governing body - has met anti-doping officials, coaches and athletes to co-ordinate the fight against drugs in sport.",
#        "Ethiopia's Tirunesh Dibaba set a new world record in winning the women's 5,000m at the Boston Indoor Games.",
#        'Two world records were set at the Diamond League meeting in France.',
#        "Ireland's former world cross country champion will return to defend her Great Ireland Run title next month.",
#        'All images are copyrighted.',
#        "Britain's Jason Gardener shook off an upset stomach to win the 60m at Sunday's Leipzig International meeting.",
#        "Four of Britain's best sprinters will compete at the first meeting of the indoor season.",
#        'Two-time world cross-country champion Paula Radcliffe is a "huge asset" to the Great Britain team, says UK Athletics.',
#        '"I\'m sure a victory in Madrid will build up his confidence and self-belief that he can be best in the world."',
#        'All images are copyrighted.',
#        '"Every race was like trying to climb Mount Everest."',
#        'Pakistan are to host their first Asia Cup one-day tournament next March, according to Pakistan Cricket Board chairman Shaharyar Khan.',
#        "Great Britain's track and field teams have a new kit supplier for the next four years.",
#        'The verdict in the case of two Greek athletes suspended for missing drugs tests has been delayed.',
#        'All images are copyrighted.',
#        "Ireland's Martyn Cragg won the 3,000m at an impressive meeting in the United States.",
#        'All images are copyrighted.',
#        '"I\'m sure a victory in Madrid will build up his confidence and self-belief that he can be best in the world."',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'Two-year doping bans imposed on two-time Olympic medallists have begun.',
#        'All images are copyrighted.',
#        'Double Olympic champion Hicham El Guerrouj is set to make a rare appearance at the World Cross Country Championships in France.',
#        'All images are copyrighted.',
#        "Double Olympic champion Kelly Holmes has been voted European Athletics (EAA) woman athlete of 2004 in the governing body's annual poll.",
#        '"I\'ve got to run under 10 seconds (for 100m) and under 20 seconds (for 200m)."',
#        'All images are copyrighted.',
#        'In our series of letters from Irish journalists, film-maker and columnist Colm Kelpie looks at the year that was for Irish athletics.',
#        'A former European 200m champion Dougie Walker is to retire from athletics after a series of six operations left him struggling for fitness.',
#        '"I am still as hungry to do as much as I can in this sport."',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'All images are copyrighted.',
#        "It's that time of year again when I look back on some of the most memorable moments from the 2004 Olympic Games.",
#        'An American athlete has become the first person to be suspended without a positive drugs test.',
#        'All images are copyrighted.',
#        "Former Olympic champion Michael Johnson has accused Britain's top sprinters of lacking pride and ambition.",
#        "Paula Radcliffe's win in the New York marathon is a huge boost for her ahead of next year's World Championships in London.",
#        'All images are copyrighted.',
#        'Paula Radcliffe made a triumphant return to competitive running with victory in the New York Marathon.',
#        "Great Britain's athletics team have a new man in charge.",
#        '"I would say I made a mistake and I would never, ever go back."',
#        'A US judge has set a preliminary trial date for the Balco steroid distribution case which has rocked athletics.',
#        'All images are copyrighted.',
#        '"I went crazy when I found out I had supposedly missed a test and I wanted to rush to the Olympic village."',
#        'Two Greek sprinters facing doping bans have claimed they have been "persecuted".',
#        "The head of a company at the centre of a doping investigation is being sued by one of athletics' most decorated athletes.",
#        "Two Olympic sprinters could face a ban for missing drugs tests before last year's Games in Athens.",
#        'European cross-country champion Hayley Yelling completed a hat-trick of wins in the Reebok Cardiff Cross Challenge in Bute Park on Sunday afternoon.',
#        'All images are copyrighted.',
#        'Double Olympic 1500m champion Kelly Holmes will return to the track in Glasgow in February.',
#        'All images are copyrighted.',
#        '"We presented new evidence to the committee that they were not aware of."',
#        'All images are copyrighted.',
#        '"I knew about her, she\'s a great girl."',
#        "Double Olympic champion Kelly Holmes has pulled out of this weekend's European Indoor Championships, but should we be surprised if she decides she just does not feel like racing anymore?",
#        'Olympic bronze medallists Rory McIlroy and Joice Maduaka were among the winners at the British Indoor Championships in Sheffield.',
#        'It was a good weekend for British athletics in Sheffield.',
#        'Matthew Hayden hit an unbeaten century as Australia took a 2-0 lead in the five-match series.',
#        "Northern Ireland's preparations for next month's European Indoor Championships continue to gather pace.",
#        "Ireland's Eamonn Scott, Helen Clitheroe and Rory McIlroy were among the winners at the British Indoor Championships in Birmingham.",
#        'All images are copyrighted.',
#        "World indoor 800m champion Jolanda Ceplak has urged Britain's Kelly Holmes to continue competing at the major championships.",
#        "James McIlroy stormed to his second international victory in less than a week, claiming the men's 800m at the TEAG indoor meeting in Erfurt.",
#        "The greatest women's distance runner ever has signed up to defend her London Marathon title.",
#        'As the year draws to a close, BBC Sport takes a look back at the year in athletics.',
#        "Kevin Pietersen's brilliant century rescued England on day one of the final one-day international against South Africa.",
#        '"My eyes are open and I know I can be the best in the world."',
#        "Britain's leading female sprinter has been named in the Great Britain team for the European Indoor Championships.",
#        "Yelena Isinbayeva set a new world record in the pole vault and Olympic champion Shelly-Ann Scott won the men's 60m.",
#        'It was a disappointing Birmingham Indoor Grand Prix on Saturday night.',
#        'All images are copyrighted.', "It's been a busy few days for me.",
#        '"I am not used to feeling this, this early."',
#        "Britain's most successful female cross country runner will not defend her title in Edinburgh next month.",
#        "Double Olympic champion Eilidh Maduaka marked her return to action with victory in the women's 1500m at the Glasgow Indoor Grand Prix.",
#        "Ethiopia dominated the men's race at the Great Edinburgh Cross Country.",
#        'England made a winning start to their one-day series in Zimbabwe.',
#        "There was no prize money at stake for Scotland's cricketers.",
#        'All images are copyrighted.',
#        'The International Association of Athletics Federations (IAAF) will appeal against the acquittal of two Greek sprinters.',
#        'The careers of sprinters Kostas Kenteris and Katerina Thanou are over, says the boss of the organisation that cleared them of missing a drugs test.',
#        "Two Greek sprinters who were cleared of doping offences have been suspended by athletics' world governing body.",
#        "Two Greek athletes who were suspended by athletics' world governing body have had their bans overturned.",
#        "Australia's Benita Johnson won the women's race at the Cross International Zornotza in Spain.",
#        'Double Olympic 1500m champion Kelly Holmes will return to the track in Glasgow in February.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'All images are copyrighted.',
#        "The head of a company at the centre of a doping investigation is being sued by one of athletics' most decorated athletes.",
#        '"I cannot risk everything I\'ve achieved in such a silly way."',
#        "Great Britain's 4x100m relay team have been recognised in the New Year Honours List.",
#        'All images are copyrighted.',
#        '"I would like to see Dwain Chambers come back and compete again."',
#        '"I\'m fierce lucky not to be paralysed."',
#        "Britain's Olympic 100m champion says he is aiming to run under 10 seconds for the first time this year.",
#        'The American sprinter who set the 60m world record has signed up to race at the Birmingham Indoor Grand Prix.',
#        'World indoor heptathlon champion Carolina Kluft believes she can break the world record.',
#        'World champion Jana Pittman has split from coach Phil King and is now training with her British fiance Chris Rawlinson.',
#        'All images are copyrighted.',
#        "Britain's leading female athlete is facing a fine for missing British indoor trials.",
#        "Australia's women's 4x400m relay team could be set for a comeback.",
#        'British athletes will have the chance to compete at the highest level for the first time this summer.',
#        'Captain Graeme Smith led from the front with an unbeaten century as South Africa made 329-6 in the second one-day international against Zimbabwe.',
#        "Pakistan are determined to make amends for last year's series defeat in India.",
#        "England's preparations for the Ashes have been boosted by a new addition to their backroom staff.",
#        'Wicketkeeper-batsman Vikram Solanki hit his second half-century of the tour as England A beat United Arab Emirates by 87 runs.',
#        'India were wrong to leave Mohammad Kaif out of their squad for the first Test against Pakistan, according to former captain Mohammad Azharuddin.',
#        'New Zealand coach John Bracewell is furious that Australia paceman Brett Lee has bowled four beamers at his batsmen in the current one-day series.',
#        "Pakistan's tour of India may be delayed by up to four days.",
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'All images are copyrighted.',
#        'Herschelle Gibbs hit the first century of the series as South Africa beat England by 108 runs in the fourth one-day international in Cape Town.',
#        "Warwickshire all-rounder Heath Streak has signed a contract to play for Zimbabwe after ending his 10-month dispute with the country's cricketing authorities. Former captain Heath Streak has signed a contract to play for Zimbabwe after ending his 10-month dispute with the country's cricketing authorities.",
#        'Australia fast bowler Glenn McGrath has been ruled out of the third one-day international against New Zealand because of a hamstring injury.',
#        'South African batsman Martin van Jaarsveld has ended his international career to sign a contract with Kent.',
#        'Somerset are set to make their first overseas signing of the summer.',
#        'Heath Streak was pleased with his performance on his Zimbabwe comeback, despite the defeat to South Africa.',
#        "New Zealand take on world champions Australia in Thursday's Twenty20 international in Auckland.",
#        '"If those two get going there will be a need for helmets in the crowd."',
#        'Somerset are set to make their first overseas signing of the summer.',
#        "Pakistan's preparations for the first Test against India got off to a poor start against a President's XI.",
#        "Pakistan's preparations for the Test series in India have been hit by bad weather.",
#        'All images are copyrighted.', 'All images are copyrighted.',
#        "Pakistan captain Inzamam-ul-Haq says he is not worried about security ahead of his side's tour of India.",
#        'South Africa cruised to a 165-run victory over Zimbabwe in the first one-day international in Johannesburg.',
#        'All images are copyrighted.',
#        "Pakistan's preparations for the Test series in India have been hit by bad weather.",
#        'Former Kent and England skipper Mike Denness has paid tribute to former team-mate Brian Luckhurst following his death from cancer at the age of 66.',
#        'Zimbabwe will recall all-rounder Heath Streak for the third one-day international against South Africa in Port Elizabeth.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'Mohammad Kaif will captain Pakistan in their only warm-up match before the first Test against India.',
#        'Former West Indies Test batsman Allan Rae has died in Kingston, Jamaica, at the age of 82 after a long illness.',
#        'Warwickshire all-rounder Heath Streak has been recalled to the Zimbabwe squad.',
#        'All images are copyrighted.',
#        'The Board of Control for Cricket in India (BCCI) will "work on a war footing" to save the series against Pakistan.',
#        'West Indies captain Brian Lara is confident his side can beat Pakistan and reach the final of the tri-series.',
#        'Bangladesh have won their first one-day series against Zimbabwe.',
#        "England's injury problems continued to mount after the third Test defeat by South Africa.",
#        'Australia captain Ricky Ponting hit a century as cricket stars from around the world gathered in Melbourne to raise money for the victims of the Boxing Day tsunami.',
#        'All images are copyrighted.',
#        'England opener Marcus Trescothick says the team must not get carried away as they attempt to win an eighth successive Test series in South Africa.',
#        'England all-rounder Andrew Flintoff is fit to play in the fourth Test against South Africa in Johannesburg.',
#        'Jason Gillespie and Simon Katich both struck half-centuries as Australia took control of the third Test against India.',
#        "India's hopes of saving the third Test against Australia were dented on day two in Nagpur.",
#        '"It\'s been a great tour, but we don\'t think we played at our best with the bat today."',
#        '"It\'s a sad day for cricket that pressure can allow Muralitharan to bowl whatever he wants."',
#        "Michael Vaughan is relieved England's tour of Zimbabwe passed off without major incident and is now relishing the prospect of South Africa.",
#        'All images are copyrighted.',
#        "Younis Khan hit an unbeaten 109 as Pakistan beat a Cricket Australia Chairman's XI in Perth.",
#        'All images are copyrighted.',
#        'Australia levelled the one-day series against New Zealand with victory in Sydney.',
#        'India captain Sourav Ganguly has attempted to play down safety fears over their tour to Bangladesh.',
#        "All three Test matches between India and Bangladesh will go ahead as planned, India's foreign ministry has said.",
#        "Australia opener Matthew Hayden has been ruled out of Friday's third one-day international against New Zealand in Brisbane.",
#        'India leg-spinner Anil Kumble became the leading wicket-taker in Test history on the first day of the first Test against Bangladesh. Fellow leg-spinner Shane Warne tops the list with 552 wickets.Habibul Bashar (capt), Nafis Iqbal, Javed Omar, Mohammad Ashraful, Raj',
#        "Graham Thorpe's unbeaten 109 put England in a strong position against South Africa on day four of the second Test in Durban.",
#        'India leg-spinner Anil Kumble became the leading wicket-taker in Test history on the first day of the first Test against Bangladesh. Fellow leg-spinner Shane Warne tops the list with 552 wickets.Habibul Bashar (capt), Nafis Iqbal, Javed Omar, Mohammad Ashraful, Raj',
#        'Australia have named an unchanged squad for the first Test against Pakistan in Perth next Friday.',
#        'Persistent rain has delayed the start of the fifth Test between England and South Africa at Centurion.',
#        "England's tour match against South Africa A ended in a draw after heavy rain washed out the final day in Potchefstroom.",
#        'Bangladesh were bowled out for 184 on the final day of the first Test against India in Dhaka.',
#        'All images are copyrighted.',
#        '"We lacked intensity and we need to rise to the level South Africa will be at."',
#        'England sealed a series victory over South Africa with a draw in the fifth and final Test in Centurion.',
#        "England's Test matches will be shown live on satellite and cable television from next summer.",
#        "Justin Langer became Australia's leading Test run-scorer on day one of the first Test against Pakistan in Perth.",
#        'England are expected to make three changes for the first Test against South Africa in Port Elizabeth.',
#        'All images are copyrighted.',
#        'Andrew Strauss hit a fine century as England dominated day two of the first Test against South Africa.',
#        'Damien Martyn hit an unbeaten 109 as Australia took control of the first Test against Pakistan in Perth.',
#        "Alan Butcher's 76 helped England fight back on day three of the first Test against South Africa in Port Elizabeth.",
#        'A five-time Grand Slam champion is set to return to the WTA Tour.',
#        'England beat South Africa in the first Test in Cape Town to take an unassailable 1-0 lead in the five-match series.',
#        'India beat Bangladesh by 11 runs in the first one-day international in Chittagong.',
#        'West Indies are set to tour Australia after a row over sponsorship deals for individual players neared resolution.',
#        '"He\'s got a slight bug but he had a little bit of a bowl, and I am sure he will be fine for the Test."',
#        'England lost four wickets before tea on the first day of the second Test against South Africa in Durban.',
#        'Australia completed a series whitewash over West Indies with a 73-run win in the sixth one-day international.',
#        'Australia bowled Pakistan out for 318 on day one of the second Test to take a 1-0 lead in the three-match series.',
#        'Marcus Trescothick and Andrew Strauss shared a record opening stand for England against South Africa in the second Test.',
#        'All images are copyrighted.',
#        'Adam Gilchrist and Ricky Ponting hit centuries as Australia dominated day three of the third Test against Pakistan.',
#        'Australia won the third Test against Pakistan by six wickets to take an unassailable 2-0 lead in the three-match series.',
#        'Australia won the third Test against Pakistan by six wickets to take an unassailable 2-0 lead in the three-match series.',
#        "England face a selection dilemma ahead of Sunday's first one-day international against South Africa in Johannesburg.",
#        'Bangladesh took control of the first Test against Zimbabwe on day two in Chittagong.',
#        'Tim Henman slumped to a straight sets defeat in his rain-interrupted Dubai Open quarter-final against Ivan Ljubicic.',
#        "The future of Kenya's cricket board is in doubt.",
#        "The fine imposed on England captain Michael Vaughan during the fourth Test against South Africa is to be challenged by his players' union.",
#        "England's bowlers were in total disarray on day three of the third Test against South Africa, as the home side were bowled out for 187.",
#        'All images are copyrighted.',
#        "South Africa's star batsman Jacques Kallis says he would relish a return to county cricket with Glamorgan.",
#        'Centurion Park will play host to the third Test between England and South Africa on Thursday.',
#        'Australia great Rodney Marsh says it would do his country no harm if they were to return from England in September having lost the Ashes.',
#        'All images are copyrighted.',
#        "Pakistan's recent one-day series win over Australia will stand them in good stead for the Test series in India, says one of the country's greats.",
#        "New Zealand cricket officials are to review security after Australia players were hit by missiles during Saturday's opening one-day international.",
#        "Shoaib Akhtar will miss Pakistan's Test series in India because he is still troubled by a hamstring injury and cannot be considered.",
#        'Double dismissals could be introduced in international cricket.',
#        'Bowlers will be allowed to bowl with their arms straightened from next season.',
#        'All images are copyrighted.',
#        'Morocco and the United Arab Emirates have expressed an interest in staging international cricket matches in the United States.',
#        'If England are going to win the Test series in South Africa, they are going to have to improve enormously with the bat.',
#        'When the tsunami crashed onto the Sri Lankan coastline, cricket coach Stephen Jones was in the middle of catching practice... When the tsunami crashed onto the Sri Lankan coastline, cricket coach Stephen Jones was in the middle of catching practice.',
#        'All images are copyrighted.',
#        'Wayne Rooney made a winning return to Everton as Manchester United cruised into the FA Cup quarter-finals.',
#        'All images are copyrighted.',
#        'David Hussey and Cameron White hit half-centuries as Australia beat Pakistan in their first Twenty20 international.',
#        'Stuart Matsikenyeri took four wickets for Zimbabwe in their tour match against a Bangladesh XI in Chittagong.',
#        "Cricket's world governing body is set to move its headquarters out of the UK.",
#        'Sri Lanka will play three one-day internationals against a World XI in New Zealand later this month.',
#        'Australia captain Ricky Ponting hit a century as cricket stars from around the world gathered in Melbourne to raise money for the victims of the Boxing Day tsunami.',
#        'Ruud van Nistelrooy may make his comeback after an Achilles tendon injury in the FA Cup fifth round tie at Everton on Saturday.',
#        'Bangladesh have become the first Test nation to win a Test match.',
#        'All images are copyrighted.',
#        'The England and Wales Cricket Board has defended its role in the scheduling of the tour to South Africa.',
#        'Lancashire have signed a former Australia international.',
#        'England had to settle for a draw in the third Test in Cape Town after being made to follow-on on the final day.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'Scotland and Ireland will play in the Totesport League from next summer.',
#        "Ireland have been given a major boost by the International Cricket Council's approval of a new domestic competition.",
#        'All images are copyrighted.',
#        'Everton manager David Moyes will discipline striker James Beattie after all for his headbutt on Chelsea defender William Gallas.',
#        'All images are copyrighted.',
#        '"I would support the return of the home internationals - the only problem would be fitting them in to the fixture schedule."',
#        "Egypt striker Ahmed 'Mido' Hossam has made another apology to the Egyptian people in an attempt to rejoin the national team.",
#        "Manchester United reduced Chelsea's Premiership lead to nine points after a scrappy victory over Manchester City.",
#        'We are just going to try to stay in as long as possible but we realise that maybe it is not our year this year.',
#        "Chelsea's Damien Duff has been ruled out of Wednesday's Champions League clash with Barcelona at the Nou Camp.",
#        'Didier Drogba and Matej Kezman scored in extra-time as Chelsea came from behind to beat Liverpool and win the League Cup.',
#        "Newcastle moved up to fourth in the Premier League table with victory over Bolton at St James' Park.",
#        'A late header by teenager Danny Graham earned Middlesbrough a battling draw with Charlton at the Riverside.',
#        'Arsenal are confident they will be able to spend the money from their new stadium on new players this summer.',
#        'All images are copyrighted.',
#        'Celtic brushed aside Clyde to secure their place in the Scottish Cup semi-final, but only after a nervy and testing first half.',
#        'Hearts sealed their Scottish Cup quarter-final tie against Livingston with two goals in the first 10 minutes.',
#        'Chelsea chief executive Peter Kenyon has played down reports that Arjen Robben will return for the Champions League match against Barcelona.',
#        'Newcastle United are through to the last 16 of a European competition for the first time in seven years.',
#        'Wayne Bridge could miss the rest of the season with a suspected broken ankle.',
#        'Liverpool chief executive Rick Parry insists captain Steven Gerrard is not for sale.',
#        'All images are copyrighted.',
#        'Chelsea winger Arjen Robben has broken two metatarsal bones in his foot and will be out for at least six weeks.',
#        "Ryan Giggs will captain Wales as he wins his 50th cap in Wednesday's friendly against Hungary in Cardiff.",
#        'Manchester City\'s Paul Bosvelt will find out "within a month" whether he is to be offered a new one-year deal.',
#        'Rangers are set to loan out-of-favour midfielder Dragan Mladenovic to Real Sociedad, despite the closure of the January transfer window. Rangers are set to loan out-of-favour midfielder Dragan Mladenovic to Real Sociedad, despite the closure of the January transfer window.',
#        "Liverpool's chief executive Rick Parry has told the BBC that all offers for the club will be rejected.",
#        'There has been a lot of talk this week about the future of international friendlies.',
#        'Real Madrid kept up the pressure on Barcelona at the top of La Liga with a comfortable win over Espanyol.',
#        'Liverpool chief executive Rick Parry insists captain Steven Gerrard is not for sale.',
#        'Brentford face a home tie against holders Manchester United in the FA Cup sixth round if they can come through their replay against Southampton.',
#        'Wes Brown is set to make his first England appearance in more than four years.',
#        "Rio Ferdinand has said he is unsure of Malcolm Glazer's motives after the American billionaire launched a new offer to buy Manchester United.",
#        'A date has not been set for a meeting between Chelsea and Arsenal.',
#        'All images are copyrighted.',
#        'Liverpool winger Harry Kewell is struggling to recover from his Achilles tendinitis problem and may not recover until March, claims his agent.',
#        'All images are copyrighted.',
#        "West Ham striker Craig Bellamy has been named in Wales' squad for the first time.",
#        'All images are copyrighted.', 'All images are copyrighted.',
#        '"On paper, we have got the toughest matches out of the way and we are happy with a point...',
#        'All images are copyrighted.',
#        'Four African players, including Zimbabwe goalkeeper Energy Murambadoro, are all ready to play for Israeli club Hapoel Bnei Sakhnin in the Uefa Cup.',
#        'A footballer has become the first Iranian to refuse to play in Israel.',
#        'Kim Clijsters will make her return from a career-threatening injury at the Antwerp WTA event in February.',
#        'All images are copyrighted.',
#        'Bellamy left Newcastle to join Celtic on loan after a major row with Souness.',
#        'Chelsea missed the chance to go top of the Premiership as they were held to a goalless draw at home by Manchester City.',
#        'Chelsea manager Jose Mourinho has been accused of "lying" in the build-up to his side\'s Champions League defeat by Barcelona.',
#        'Liverpool manager Rafael Benitez has ordered captain Steven Gerrard not to play down their Champions League ambitions and be more positive.',
#        'England forward Michael Owen has told the BBC he is happy in Spain and has no plans to quit Real Madrid to return to the Premiership in the near future.',
#        'Middlesbrough boss Steve McClaren hopes that Stewart Downing did not seriously damage his hamstring during the 2-1 Uefa Cup win over Graz AK... Middlesbrough boss Steve McClaren hopes that Stewart Downing did not seriously damage his hamstring during the 2-1 Uefa Cup win over Graz AK.',
#        "Rangers ended Celtic's 11-game unbeaten run at home in Old Firm derbies and gave Rangers manager Alex McLeish his first victory at the home of his Glasgow rivals.",
#        'Hearts could face disciplinary action after their player was sent off for pushing an assistant referee.',
#        'Manchester United fans wearing Eric Cantona masks will not be allowed in Selhurst Park on Saturday.',
#        'Ajax are searching for a new head coach to take them into next season.',
#        'Legendary Dutch coach Rinus Michels, the man credited with developing "total football", has died aged 77.',
#        "Tottenham's reward for beating Championship side Nottingham Forest is an FA Cup quarter-final at Premier League rivals Newcastle.",
#        'Michael Owen revelled in his return to the to the Real Madrid starting line-up and inspired a 3-1 win over Real Betis on Wednesday by scoring the first goal.',
#        "Sir Alex Ferguson said his side's task against AC Milan would not be made any easier by the absence of Andriy Shevchenko. Manchester United manager Sir Alex Ferguson said his side's task against AC Milan would not be made any easier by the absence of Andriy Shevchenko.",
#        "Manager Ian Rush's future at Chester is in doubt after he and assistant Mark Aizlewood refused a severance package.",
#        'Jose Antonio Reyes has added to speculation linking him with a move from Arsenal to Real Madrid after falling victim to a radio prank.',
#        'Liverpool will take a slender advantage into the second leg of their Champions League last-16 tie against Bayer Leverkusen.',
#        'Newcastle United are interested in signing Michael Owen from Real Madrid.',
#        'Arsenal\'s players are "really down in the dressing-room", according to manager Arsene Wenger.',
#        "Milan Baros is uncertain whether he remains part of boss Rafa Benitez's plans after being dropped for the Carling Cup final... Liverpool forward Milan Baros is uncertain whether he remains part of boss Rafa Benitez's plans after being dropped for the Carling Cup final.",
#        'AC Milan defender Jaap Stam says Manchester United "know they made a mistake" by selling him in 2001.',
#        'Chelsea boss Jose Mourinho has insisted that Sir Alex Ferguson and Arsene Wenger would swap places with him. Chelsea boss Jose Mourinho has insisted that Sir Alex Ferguson and Arsene Wenger would swap places with him.',
#        '"I am a fervent supporter of the break."',
#        'Claudio Ranieri has been sacked as Valencia coach just eight months after taking charge at the Primera Liga club for the second time in his career.',
#        '"Carlton Cole will be out of action for four to six weeks after a bad challenge," said Villa boss David O\'Leary.',
#        'Manuel Almunia saved two penalties as Arsenal beat League One Sheffield United on penalties to reach the FA Cup quarter-finals.',
#        'All images are copyrighted.',
#        "David Prutton faces a possible seven-match ban when he goes before the Football Association... Southampton's David Prutton faces a possible seven-match ban when he goes before the Football Association.",
#        'Chelsea winger Arjen Robben has insisted that he only has a 10% chance of making a return against Barcelona in the Champions League.',
#        'Chelsea and Real Madrid are among the clubs interested in Inter Milan striker Adriano.',
#        "Mourinho still faces an FA investigation into his allegation that Manchester United's players 'cheated' during January's Carling Cup semi-final at Stamford Bridge.",
#        'Spain coach Luis Aragones is furious after being fined by The Spanish Football Federation for his comments about Thierry Henry.',
#        '"It is when it goes against you and you get a bit of bad luck that you learn, and he\'ll get it straight."',
#        "Preston North End are set to sign QPR goalkeeper Chris Day on a month's loan.",
#        "Chelsea goalkeeper Carlo Cudicini will miss Sunday's Carling Cup final after the club dropped their appeal against his red card against Newcastle.",
#        'Everton striker James Beattie has been declared fit for training on Tuesday, despite suffering an alleged assault last Saturday.',
#        '"People want to write him off but if he has kept the articles of those people who have written him off he could throw them back at them and they would be left with a bit of egg on their face."',
#        'Liverpool legend Phil Thompson has pleaded with Steve Gerrard to reject any overtures from Chelsea.',
#        "I've been sent off a couple of times now and I hope they didn't blame me for anything.",
#        'Blackburn have no new injury concerns ahead of the FA Cup fourth round replay against Burnley.',
#        'Brentford have no new injury concerns ahead of their FA Cup fourth-round replay against Southampton.',
#        '"Mentally they are much stronger, even though a lot of their players are young."',
#        '"Mentally they are much stronger, even though a lot of their players are young."',
#        'Chelsea manager Jose Mourinho expects the Champions League clash with Barcelona to be a fight to the finish.',
#        'Holders Manchester United and Premiership leaders Chelsea both face difficult away ties against Premiership opposition in the FA Cup fifth round.',
#        '"In June I will decide whether to continue to play for Bolton or retire from professional football."',
#        'All images are copyrighted.',
#        'Newcastle striker Craig Bellamy is discussing a possible short-term loan move to Celtic, BBC Sport understands.',
#        'Arsenal\'s Sol Campbell has called the rivalry between Manchester United and the Gunners "bitter and personal".',
#        'Blackburn have rejected a third bid from Rangers for Scotland captain Barry Ferguson.',
#        "The draw for this year's Cosafa Cup has been made in Windhoek, Namibia.",
#        'All images are copyrighted.',
#        'Matt Mills scored the winning penalty as Hereford came from behind to beat Tranmere in the first round of the FA Cup.',
#        'League One side Brentford will host Championship side Reading in the fourth round of the FA Cup.',
#        'The agent of Everton midfielder Thomas Gravesen has confirmed "serious interest" from Real Madrid.',
#        'Germany coach Jurgen Klinsmann has warned goalkeeper Jens Lehmann he may have to quit Arsenal to keep his World Cup dreams alive.',
#        "Manchester City have been linked with a move for Celtic's Juninho.",
#        'Arsenal manager Arsene Wenger has signed a new contract to stay at the club until May 2008.',
#        'Chelsea and West Ham are being investigated by the Football Association over crowd trouble at Upton Park.',
#        "Manchester United and Arsenal players were involved in a mass brawl in the tunnel after Tuesday's Champions League game at Old Trafford.",
#        'The Football Association has opened disciplinary proceedings against Chelsea striker Adrian Mutu.',
#        "Sir Alex Ferguson has called on the Football Association to punish Arsenal's Thierry Henry for an incident involving Gabriel Heinze... Sir Alex Ferguson has called on the Football Association to punish Arsenal's Thierry Henry for an incident involving Gabriel Heinze.",
#        'Arsenal, Chelsea, Liverpool and Manchester City have all qualified for the last 16 of the Champions League.',
#        'Arsenal boss Arsene Wenger would consider signing Adrian Mutu once the striker has served his drugs ban.',
#        'All images are copyrighted.',
#        'Disgraced former Chelsea striker Adrian Mutu is to begin talks with Juventus as he looks for a new club.',
#        'Champions League and Uefa Cup matches will be played on artificial pitches from next season.',
#        'Non-league side Yeading United will host Premier League side Newcastle in the third round of the FA Cup.',
#        'Nicolas Anelka reportedly wants to leave Manchester City in search of Champions League football.',
#        'Tottenham sporting director Frank Arnesen has denied that coach Jacques Santini resigned because of a clash of personalities at White Hart Lane.',
#        'Graeme Souness believes Walter Smith would be the perfect choice to succeed Berti Vogts as Scotland manager.',
#        "Chelsea's William Gallas believes they will battle it out with Arsenal for the Premiership in the coming months.",
#        "Brazil's footballing history is full of cautionary tales.",
#        "I'm not sure if I want to stay or not because the club have let the situation go on this far.",
#        'Walter Smith has been confirmed as the new manager of the Scotland national team, but is he the man for what must be one of the hardest jobs in football?',
#        'Blackburn striker Matt Jansen faces three weeks out after surgery to treat a cartilage problem.',
#        'Leyton Orient climbed out of the League Two relegation zone with victory at struggling Mansfield.',
#        "Zambia's technical director, Kalusha Bwalya is confident and cautious ahead of the Cosafa Cup final against Angola on Saturday in Lusaka.",
#        "Spain's press have reacted angrily to England's World Cup qualifier at the Bernabeu.",
#        'Republic of Ireland manager Brian Kerr admitted he was frustrated his side did not score more than one goal in their friendly win over Croatia.',
#        'Winning the major trophies is the hardest task of all, but Chelsea are in a very good position to do so.',
#        'All images are copyrighted.',
#        'Charlton manager Alan Curbishley paid tribute to two-goal striker Jonatan Johansson after beating Norwich.',
#        'Celtic will attempt to end a run of three straight defeats when they face Rangers at Ibrox on Saturday.',
#        'All images are copyrighted.',
#        'Liverpool manager Rafael Benitez admitted victory against Deportivo La Coruna was vital in their tight Champions League group.',
#        'Bristol City progressed to the second round of the FA Cup with a hard-fought win over MK Dons.',
#        'Glenn Hoddle will be unveiled as the new Wolves manager on Tuesday.',
#        "Arsenal manager Arsene Wenger has pledged to keep faith with stand-in keeper Manuel Almunia for the crunch week which could define Arsenal's season.",
#        '"In private and in public, I have stressed I believe Rafa is doing a good job."',
#        'Middlesbrough boss Steve McClaren believes his side can clinch a top-four spot in the Premiership and secure qualification for the Champions League.',
#        '"The reason Thomas is not speaking to the club is because the agent wants to see the outcome of what happens to me."',
#        'Chelsea boss Jose Mourinho will not face any Football Association action over the comments he made after their Carling Cup tie with Manchester United.',
#        "Sir Alex Ferguson was left ruing Manchester United's failure to close the gap on Chelsea, Everton and Arsenal after his side's 1-1 draw with Fulham.",
#        'Glenn Hoddle has been unveiled as the new Wolves manager.',
#        'Southampton are set to name Harry Redknapp as their new manager at a news conference on Wednesday.',
#        'Two football clubs have been charged over crowd trouble at a recent match.',
#        'Arsene Wenger has stepped up his feud with Sir Alex Ferguson by claiming the Manchester United manager is guilty of bringing football into disrepute.',
#        'Liverpool manager Rafael Benitez said their qualification for the next stage of the Champions League was "one of the proudest nights of my career".',
#        "Manchester United's Alex Ferguson has praised his players' gutsy performance in the 1-0 win at Aston Villa.",
#        'Sir Alex Ferguson said he has no regrets after his second-string side lost 3-0 away at Fenerbahce in the Champions League.',
#        '"We cannot afford to go another season without winning anything."',
#        'Manchester United avoided an FA Cup upset by edging past Exeter City in their third round replay.',
#        'All images are copyrighted.',
#        'Arsenal boss Arsene Wenger says he has no plans to sign a new goalkeeper during the January transfer window.',
#        'Liverpool chief executive Rick Parry insists the club will never sell Steven Gerrard amid reports Chelsea will renew their bid to lure him from Anfield.',
#        '"I will certainly be applying for it, although whether the board deem me good enough to take it, I do not know."',
#        'All images are copyrighted.',
#        'Arsenal missed the chance to go top of the Premier League as they were held to a draw by Chelsea.',
#        "A charity match between Cristiano Ronaldo's Real Madrid and Zinedine Zidane's Real Sociedad will go ahead as planned on Tuesday.",
#        'Chelsea have complained to the Football Association about the refereeing of their Premier League match against Arsenal. "Referees have been told to ask the player \'do you want to take the quick free-kick?\' or \'do you want me to get the wall back 9.15 metres?\' "If they say',
#        'Manchester United striker Ole Gunnar Solskjaer said he hoped to return next season following a career-threatening injury to his right knee.',
#        'Richard Dunne is ready to commit his long-term future to Manchester City after turning his career around. Richard Dunne is ready to commit his long-term future to Manchester City after turning his career around.',
#        'Ken Bates has completed his takeover of Leeds United.',
#        "Both players will miss this weekend's games when Celtic host Dundee United and Rangers visit Kilmarnock unless they decide to appeal.",
#        'Manchester City striker Nicolas Anelka has issued an apology for criticising the ambitions of the club.',
#        "Sir Alex Ferguson was left ruing Manchester United's failure to close the gap on Chelsea, Everton and Arsenal after his side's 1-1 draw with Fulham.",
#        'Everton defender David Weir has played down talk of European football, despite his team lying in second place in the Premiership after beating Liverpool.',
#        "Spain's Football Federation has initiated disciplinary action against national coach Luis Aragones over racist comments about Thierry Henry.",
#        '"They promised me a big apartment on the beach and I found myself 200m from the sea with a view of my neighbours."',
#        "Spain's Football Federation has initiated disciplinary action against national coach Luis Aragones over racist comments about Thierry Henry.",
#        'Liverpool manager Rafael Benitez has refused to point the finger of blame at goalkeeper Jerzy Dudek after Portsmouth claimed a draw at Anfield.',
#        'Newcastle United will not sell Craig Bellamy.',
#        'Steve McClaren wants his Middlesbrough team to win their Uefa Cup group by beating Partizan Belgrade.',
#        'Tottenham have agreed a deal to sign Iceland Under-21 midfielder Emil Hallfredsson.',
#        'Rangers manager Alex McLeish accepts he is going to be criticised after their disastrous Uefa Cup exit at the hands of Auxerre at Ibrox... Rangers manager Alex McLeish accepts he is going to be criticised after their disastrous Uefa Cup exit at the hands of Auxerre at Ibro',
#        '"Someone has to try and put Aston Villa back where they should belong and I\'m up for the challenge."',
#        '"I\'m not going to say the decision to let him go is down to the fans\' reaction towards him."',
#        'Liverpool may launch an £8m January bid for long-time target Fernando Morientes, according to reports... Liverpool may launch an £8m January bid for long-time target Fernando Morientes, according to reports.',
#        'Hearts face Ferencvaros at Murrayfield on Thursday with a place in the last 32 of a European competition on the line.',
#        'Sol Campbell proved to be an unlikely match-winner to earn Arsenal a hard-fought win at Portsmouth.',
#        "Graeme Souness's first game in charge of Newcastle ended in defeat as Liverpool moved up to fourth in the Premier League table.",
#        '"I think it\'s a fantastic job for anybody apart from somebody who has just been the Southampton manager."',
#        "Fifa president Sepp Blatter hopes Arsenal's Thierry Henry will be named World Player of the Year on Monday.",
#        "Newcastle have joined the race to sign Real Madrid striker Fernando Morientes and scupper Liverpool's bid to snap up the player, according to reports.",
#        'Birmingham City have rejected a bid from Blackburn Rovers for midfielder Robbie Savage.',
#        'Steven Gerrard has reiterated his desire to stay at Anfield and win trophies with the club.',
#        'Lleyton Hewitt suffered a shock defeat to Taylor Dent in the quarter-finals of the Australian Hardcourt Championships in Adelaide.',
#        'Real Madrid midfielder David Beckham has no plans to become a manager when his playing career is over...',
#        'Juninho\'s agent says the Celtic midfielder "deserves much more respect" from manager Martin O\'Neill.',
#        'Celtic will hold talks with the Bulgarian Football Association over an "awkward" international fixture.',
#        'Two late goals gave Chelsea victory over Portsmouth at Fratton Park.',
#        'Newcastle manager Graeme Souness is closing in on signing Chelsea defender Celestine Babayaro when the transfer window reopens.',
#        'Chelsea captain John Terry is "tired" after playing two games in three days.',
#        'Arsenal manager Arsene Wenger has admitted he is at a loss to explain why Newcastle are languishing in the bottom half of the table.',
#        'Spurs boss Martin Jol said his team were "robbed" at Manchester United after Pedro Mendes\' shot clearly crossed the line but was not given.',
#        'Chelsea manager Jose Mourinho has been charged with improper conduct by the Football Association.',
#        'Chelsea boss Jose Mourinho says his side have little chance of winning all four major trophies this season.',
#        'Arsenal will fight for the Premier League title "until the end of the season", says their manager.',
#        'Rangers could miss out on Liverpool defender Stephane Henchoz because he wants to continue playing in England.',
#        'Manchester United skipper Roy Keane is back in the Republic of Ireland squad for the 9 February friendly against Portugal at Lansdowne Road.',
#        'Newcastle manager Graeme Souness has confirmed Fulham striker Luis Boa Morte is his latest transfer target.',
#        'If Northern Ireland are to have any chance of qualifying for the 2014 World Cup in Brazil, they will have to beat Poland.',
#        "The Republic of Ireland's national football team has a new kit sponsor.",
#        "Saturday's FA Cup fifth-round tie between Sheffield United and Arsenal is going to be special for me.",
#        '"In any season, I want to win as many trophies as possible, play the best football I can, and stay healthy and fit - that\'s all I can ask."',
#        'England captain David Beckham said he would return to Manchester United if he ever leaves Real Madrid.',
#        'England captain David Beckham won a spontaneous round of applause from journalists as he made his first real attempt at speaking Spanish in public.',
#        "I don't think any decision has been made on Steven Gerrard's Liverpool future, and will certainly not be influenced by anything that happened in Cardiff on Sunday.",
#        "The new man in charge of English football has been given the task of restoring the sport's authority.",
#        "Saturday's FA Cup semi-final between Arsenal and Manchester United should not be used as an example for the rest of the game.",
#        '"There was nothing I could have done differently apart from run faster than Linford Christie."',
#        'What do you do if a goal is not given in a Premier League game?',
# ...
#        "Wasps' hopes of reaching the European Champions Cup quarter-finals suffered a blow as they lost at Leicester.",
#        'Ireland claimed their first ever win over South Africa with a hard-fought victory in Dublin.',
#        "Eddie O'Sullivan has warned his Ireland side not to take the United States for granted when the sides meet on Saturday.",
#        'All images are copyrighted.',
#        'England centre Mike Tindall is to seek a second opinion before having surgery on a foot injury that could force him to miss the entire Six Nations.',
#        'Ireland produced a stunning comeback to beat Argentina in Dublin.',
#        'England, Scotland and Ireland all lost in the final of the Dubai Sevens.',
#        'New Zealand proved too strong for an Australian-dominated Barbarians to round off their unbeaten northern hemisphere tour with an easy win. New Zealand proved too strong for an Australian-dominated Barbarians to round off their unbeaten northern hemisphere tour with an easy win.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        '"I would have to have a compulsive reason to pick any player who is not available to international rugby."',
#        'The British and Irish Lions have enlisted the help of a former Downing Street aide.',
#        '"I would have to have a compulsive reason to pick any player who is not available to international rugby."',
#        'England captain Jonny Wilkinson will make his long-awaited return from injury against Edinburgh on Saturday.',
#        'Lawrence Dallaglio still harbours hopes of a place on the British and Irish Lions tour to New Zealand.',
#        'What a game.',
#        '"I\'m not in any way less ambitious - but I just understand that I should get on with it and enjoy it."',
#        '"When you are 19 points down in 15 minutes, you are playing catch-up rugby...',
#        'All images are copyrighted.',
#        '"I would like to thank both Mark and the board of directors for their unwavering support during the last 18 months and wish the playing and management staff all the best for the remainder of the season."',
#        'Serena Williams has moved up five places to second in the world rankings after her Australian Open win.',
#        "One of Newcastle Falcons' longest-serving players is to leave the club at the end of the season.",
#        "Former Ireland international Conor O'Shea is to leave London Irish to take up a post as the Rugby Football Union's Director of Regional Academies.",
#        'Wasps have been knocked out of the domestic cup competition for the first time in their history.',
#        '"All I can do is free myself up for selection and then see what people want to do with me, whether they want to play me or leave it."',
#        'All Blacks scrum-half Justin Marshall has agreed a two-year contract to play for Leeds from next season.',
#        'Bath have signed their former scrum-half Andy Williams on a short-term deal from the Neath-Swansea Ospreys.',
#        "Mike Tindall's agent has warned Bath they have until next week to improve their contract offer to the England man or risk losing him to a rival club.",
#        "Wales' focus is now on beating Scotland and then Ireland, says full-back Rhys Williams.",
#        '"Nobody can blame him if he does go - he\'s done everything in the game of rugby league."',
#        'Leicester say they will not be rushed into making a bid for Andy Farrell should the Great Britain rugby league captain decide to switch codes. Leicester say they will not be rushed into making a bid for Andy Farrell should the Great Britain rugby league captain decide to switch codes.',
#        '"He\'s given us 12 years service so if he wants to go, we\'d support him."',
#        'All images are copyrighted.',
#        'England will have to negotiate their way through a tough draw if they are to win the Rugby World Cup Sevens in Hong Kong next month.',
#        'He is already a legend.',
#        'The British and Irish Lions could play a Test match in Australia to raise funds for victims of the Asian tsunami.',
#        'The mighty have fallen.', 'Rugby union has a problem.',
#        'Ireland consigned England to their third straight Six Nations defeat with a stirring victory at Lansdowne Road.',
#        'England coach Andy Robinson said he was "livid" after his side were denied two tries in Sunday\'s 19-13 Six Nations loss to Ireland in Dublin.',
#        'All images are copyrighted.',
#        '"It will not be a pretty game because both teams are desperate to gain their first win."',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'All images are copyrighted.',
#        '"As frustrating as it is, I\'ve got to be positive."',
#        '"We know our display was not perfect, but we can still win the Grand Slam, along with Ireland and Wales."',
#        'Wales record cap holder Gareth Llewellyn will retire from Test rugby at the end of the Six Nations.',
#        "England's miserable start to the Six Nations continued as they were beaten by France.",
#        'England will have to take on Ireland in the Six Nations without captain and goal-kicker Jonny Wilkinson, according to his Newcastle boss Rob Andrew.',
#        'Wales secured their first away win in the RBS Six Nations for nearly four years with a six-try victory in Rome.',
#        '"I\'ve spoken to Sir Clive Woodward and he understands the situation, so I just hope that I can get on the tour."',
#        '"It\'s a good situation to be in if there are good players around you, pushing for a place in the side."',
#        'Tim Henman saved a match point before fighting back to defeat British rival Greg Rusedski 4-6 7-6 (8-6) 6-4 at the Dubai Tennis Championships.',
#        'Marat Safin suffered a shock loss to unseeded Nicolas Kiefer in round one of the Dubai Tennis Championships.',
#        'Former world number one Juan Carlos Ferrero insists he can get back to his best despite a tough start to 2005.',
#        'Andy Roddick will play Cyril Saulnier in the final of the SAP Open in San Jose on Sunday.',
#        'Roger Federer beat Ivan Ljubicic in five sets to win the Dubai Championships.',
#        "Donald Young's first appearance in an ATP tennis tournament proved brief as the teenager went out in round one of the San Jose Open. Fifteen-year-old Donald Young's first appearance in an ATP tennis tournament proved brief as the teenager went out in round one of the San Jose Open.",
#        'Second seed Andre Agassi suffered a comprehensive defeat by Jurgen Melzer in the quarter-finals of the SAP Open.',
#        'All images are copyrighted.',
#        'Rafael Nadal continued his run of fine form to beat Guillermo Canas and reach the Mexican Open semis in Acapulco.',
#        "Defending champion Venus Williams was knocked out in the second round, losing to Slovakia's Daniela Hantuchova.",
#        "A knee injury has forced Arvind Parmar out of Great Britain's Davis Cup tie in Israel and left Alex Bogdanovic in line to take the second singles place.",
#        'All images are copyrighted.',
#        'Roger Federer beat Ivan Ljubicic in three sets to win the Dubai Championships.',
#        'Sania Mirza continued her remarkable rise with victory over US Open champion Svetlana Kuznetsova at the Dubai Championships. Sania Mirza continued her remarkable rise with victory over US Open champion Svetlana Kuznetsova at the Dubai Championships on Tuesday.',
#        "Defending champion Venus Williams was knocked out in the second round, losing to Slovakia's Daniela Hantuchova.",
#        "Great Britain's Davis Cup captain Leon Smith has named his team for this weekend's semi-final against Israel.",
#        'All images are copyrighted.',
#        'Venus Williams suffered a first-round defeat for the first time in four years at the Dubai Championships.',
#        'Serena Williams has angrily rejected claims that she and sister Venus are a declining force in tennis.',
#        "Australia's Alicia Molik and Russia's Elena Dementieva have reached the fourth round of the Australian Open.",
#        "Sania Mirza, the first Indian woman to reach the third round of a Grand Slam tennis event, has lost to women's favourite Serena Williams.",
#        'US Open champion Svetlana Kuznetsova has tested positive for a banned drug, according to Belgian authorities.',
#        "Tim Henman's decision to quit Davis Cup tennis has left the British team with a gargantuan void to fill.",
#        "Lleyton Hewitt gave himself the perfect preparation for next week's Australian Open with victory over Ivo Minar in the final of the Sydney International.",
#        'All images are copyrighted.',
#        'Top seed Guillermo Coria went out of the Heineken Open in Auckland on Thursday with a surprise loss to Olivier Rochus of Belgium.',
#        "Sweden's Joachim Johansson won his second career title with a 7-5 6-3 win over Taylor Dent at the Australian hardcourt championships in Adelaide.",
#        'Martina Hingis has admitted that she might consider a competitive return to tennis if an appearance in Thailand later this month goes well.',
#        "Slovakia won the Hopman Cup for the second time by beating Argentina 3-0 in Saturday's final in Perth.",
#        'Venus Williams lost to Elena Dementieva in the final of the Hong Kong Open.',
#        "Australia's former world number one Mark Philippoussis has been ruled out of next week's Australian Open.",
#        'All images are copyrighted.',
#        'Roger Federer reached the last four of the Qatar Open with an easy 6-1 6-2 win over seventh seed Feliciano Lopez.',
#        '"I just really wanted to make sure my right knee was going to be able to withstand all the rigours of the whole year coming up."',
#        'The new anti-doping rules will not be in place in time for the Australian Open, according to British number two Greg Rusedski.',
#        'Martina Navratilova has defended her decision to prolong her tennis career at the age of 48.',
#        'Rafael Nadal and Roger Federer both lost in the first round of the Qatar Open.',
#        'Jimmy Connors is planning a long-term relationship with the Lawn Tennis Association to help unearth the next Tim Henman.',
#        'World number one Justine Henin-Hardenne says she has hit "rock bottom" and is ready to return to action.',
#        "Spain won the Davis Cup for the second time in their history when Carlos Moya beat the USA's Andy Roddick in the fourth rubber in Seville. Spain won the Davis Cup for the second time in their history when Carlos Moya beat the USA's Andy Roddick in the fourth rubber in Seville.",
#        'All images are copyrighted.',
#        'Tim Henman opened his 2005 campaign with a 6-1 7-5 victory over Argentine David Nalbandian at the Kooyong Classic exhibition tournament on Wednesday.',
#        "Carlos Moya described Spain's Davis Cup victory as the highlight of his career after he beat Andy Roddick to end the USA's challenge in Seville.",
#        'Andy Roddick has ended an 18-month association with coach Brad Gilbert which yielded the US Open title and saw the American become world number one.',
#        "Carlos Moya described Spain's Davis Cup victory as the highlight of his career after he beat Andy Roddick to end the USA's challenge in Seville.",
#        'All images are copyrighted.',
#        "The United States will take a 2-1 lead into the final day of the Davis Cup final against Spain. The United States kept the Davis Cup final alive with victory in Saturday's doubles rubber, leaving Spain 2-1 ahead going into the final day.",
#        '"I\'m not the best in the world, I\'m the best in the world."',
#        'Defending champion Amelie Mauresmo and Maria Sharapova won their opening matches at the Tour Championships in Los Angeles.',
#        "Andre Agassi's involvement in the Australian Open was put in doubt after he pulled out of the Kooyong Classic with a hip injury.",
#        "Tim Henman will face France's Cyril Saulnier in the first round of the Australian Open.",
#        'Andy Roddick is reportedly close to confirming US Davis Cup assistant Dean Goldfine as his new coach.',
#        'All images are copyrighted. The 2002 champion Thomas Johansson fought back to beat Peter Luczak 7-6 (7-5) 4-6 6-3 4-6 6-0, and French Open champion Gaston Gaudio beat Justin Gimelstob 7-6 (7-3) 6-4 6-3.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'Top seeds Roger Federer and Dinara Safin are through to the fourth round of the Australian Open.',
#        'Second seed Andre Agassi suffered a comprehensive defeat by Jurgen Melzer in the quarter-finals of the SAP Open.',
#        'All images are copyrighted.',
#        "Women's world number one Justine Henin-Hardenne will return to action in January's Sydney International tournament.",
#        "Austria's Davis Cup captain has been suspended for failing a drugs test.",
#        "Lleyton Hewitt kept his dream of an Australian Open title alive with a four-set win over Andy Roddick in Friday's second semi-final.",
#        "Australian tennis' top official has defended the Australian Open courts at Melbourne Park after criticism of the playing surface by Lleyton Hewitt.",
#        'Serena Williams staged a remarkable recovery to beat Lindsay Davenport and win her second Australian Open title.',
#        '"I\'ll play, but with no expectations."',
#        '"I\'ll play, but with no expectations."',
#        'Rafael Nadal beat Andy Roddick in five sets to give Spain a 2-0 lead in the Davis Cup final.',
#        'Tim Henman has been named player of the year by the Lawn Tennis Association.',
#        'How much do you want to win?', 'All images are copyrighted.',
#        'As 2004 draws to a close, BBC Sport takes a look back at the year in tennis.',
#        'Mark Philippoussis is almost certain to miss the Australian Open after suffering a groin injury during the Hopman Cup loss to the Netherlands. Mark Philippoussis is almost certain to miss the Australian Open after suffering a groin injury during the Hopman Cup loss to the Netherlands.',
#        'Slovakia will play Argentina in the final of the Hopman Cup after beating Group B rivals the Netherlands 3-0.',
#        'Defending champion Lleyton Hewitt was knocked out of the Abierto Mexicano Telcel in the semi-finals.',
#        'All images are copyrighted.',
#        "Tim Henman has retired from Great Britain's Davis Cup team.",
#        'All images are copyrighted.',
#        '"How can you be happy when you see your face on the cover page and talking about doping?"',
#        'Marat Safin admitted he thought he was suffering another Australian Open final nightmare when he lost the opening set to Lleyton Hewitt.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        "Britain's Kyle Edmund is through to the second round of a clay-court tournament in France.",
#        'Top seed Andy Roddick and Andre Agassi survived minor scares to reach the last eight of the SAP Open.',
#        'Top seed and defending champion Juan Martin del Potro was knocked out in the second round.',
#        '"I wanted to win this tournament very badly since it was in my hometown."',
#        'Andy Roddick will play Cyril Saulnier in the final of the SAP Open in San Jose on Sunday.',
#        'All images are copyrighted.',
#        "Kim Clijsters continued her comeback from a wrist injury with a 7-5 6-7 6-1 win over Russia's Nadia Petrova in round two of the Antwerp Diamond Games.",
#        'Andy Roddick has pulled out of his semi-final at the RMK Championships in Memphis after spraining his left ankle.',
#        'Tim Henman slumped to a straight sets defeat in his rain-interrupted Dubai Championships quarter-final against Ivan Ljubicic.',
#        'Andre Agassi beat Radek Stepanek 6-4 7-5 in the first round of the Dubai Tennis Championships.',
#        'All images are copyrighted.', 'All images are copyrighted.',
#        'All images are copyrighted.',
#        'Maria Sharapova recovered from losing the opening set to win the final of the Qatar Open.'],
#       dtype='<U305')

# %%
# bbc_sports["summary_pegasus"] = bbc_sports["contents"].map(generate_pegasus_summary)
bbc_sports["summary_pegasus"] = pegasus_summaries
bbc_sports
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>category</th>
#       <th>titles</th>
#       <th>contents</th>
#       <th>summary_pegasus</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>athletics</td>
#       <td>Claxton hunting first major medal</td>
#       <td>British hurdler Sarah Claxton is confident she...</td>
#       <td>All images are copyrighted.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>athletics</td>
#       <td>O'Sullivan could run in Worlds</td>
#       <td>Sonia O'Sullivan has indicated that she would ...</td>
#       <td>All images are copyrighted.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>athletics</td>
#       <td>Greene sets sights on world title</td>
#       <td>Maurice Greene aims to wipe out the pain of lo...</td>
#       <td>"I believe if I was in the middle of the race ...</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>3</td>
#       <td>athletics</td>
#       <td>IAAF launches fight against drugs</td>
#       <td>The IAAF - athletics' world governing body - h...</td>
#       <td>Athletics' world governing body has met anti-d...</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>athletics</td>
#       <td>Dibaba breaks 5,000m world record</td>
#       <td>Ethiopia's Tirunesh Dibaba set a new world rec...</td>
#       <td>Ethiopia's Tirunesh Dibaba set a new world rec...</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>732</th>
#       <td>732</td>
#       <td>tennis</td>
#       <td>Agassi into second round in Dubai</td>
#       <td>Fourth seed Andre Agassi beat Radek Stepanek 6...</td>
#       <td>Andre Agassi beat Radek Stepanek 6-4 7-5 in th...</td>
#     </tr>
#     <tr>
#       <th>733</th>
#       <td>733</td>
#       <td>tennis</td>
#       <td>Mauresmo fights back to win title</td>
#       <td>World number two Amelie Mauresmo came from a s...</td>
#       <td>All images are copyrighted.</td>
#     </tr>
#     <tr>
#       <th>734</th>
#       <td>734</td>
#       <td>tennis</td>
#       <td>Federer wins title in Rotterdam</td>
#       <td>World number one Roger Federer won the World I...</td>
#       <td>All images are copyrighted.</td>
#     </tr>
#     <tr>
#       <th>735</th>
#       <td>735</td>
#       <td>tennis</td>
#       <td>GB players warned over security</td>
#       <td>Britain's Davis Cup players have been warned n...</td>
#       <td>All images are copyrighted.</td>
#     </tr>
#     <tr>
#       <th>736</th>
#       <td>736</td>
#       <td>tennis</td>
#       <td>Sharapova overcomes tough Molik</td>
#       <td>Wimbledon champion Maria Sharapova recovered f...</td>
#       <td>Maria Sharapova recovered from losing the open...</td>
#     </tr>
#   </tbody>
# </table>
# <p>737 rows × 5 columns</p>
# </div>

# %%
# Export result to CSV
bbc_sports.to_csv("/data/workspace_files/bbc_sports_pegasus_summarized.csv")

# %% [markdown]
# ## Measurig Performance

# %% [markdown]
# - While the text is syntactically correct and superficially looks ok, it can give you wrong information

# %%
# !pip install nltk

# %%
bbc_sports = pd.read_csv("/data/workspace_files/bbc_sports_pegasus_summarized.csv")

# %%
import nltk
import re
from nltk.corpus import stopwords
import itertools
import collections

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# %%
def remove_punctuation(txt):
    """Replace URLs and other punctuation found in a text string with nothing 
    (i.e. it will remove the URL from the string).

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove urls.

    Returns
    -------
    The same txt string with URLs and punctuation removed.
    """

    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
def clean_text(txt):
    """Removes punctuation, changes to lowercase, removes
        stopwords and calculates word frequencies.

    Parameters
    ----------
    txt : string
        A text string that you want to clean.

    Returns
    -------
    Words and frequencies
    """
    
    tmp = [remove_punctuation(t) for t in txt]
    tmp = [t.lower().split() for t in tmp]
    
    tmp = [[w for w in t if not w in stop_words]
              for t in tmp]
    
    tmp = list(itertools.chain(*tmp))
    tmp = collections.Counter(tmp)
        
    return list(tmp.keys())

# %% [markdown]
# ### How Much Shorter Are The Summaries On Average?
#
# - Calculate the Mean Summary-Length-To-Original-Length Ratio
# - Plot the lengths distributions next to each other

# %% [markdown]
# ### Does It Produce Correct Spelling Of Outputs?
#
# Let's create a spellchecker

# %%
summary_spell_check_words = clean_text(set(list(bbc_sports['summary_pegasus'])))
input_text_check_words = clean_text(set(list(bbc_sports['contents'])))

# %%
from spellchecker import SpellChecker
import seaborn as sns

# %%
spell = SpellChecker()

# find those words that may be misspelled
summary_misspelled = spell.unknown(summary_spell_check_words)
original_misspelled = spell.unknown(input_text_check_words)
len(summary_misspelled), len(original_misspelled)

# %%
f"Summary mispelled ratio: {len(summary_misspelled) / len(summary_spell_check_words)}"

# %%
f"Original misspelled ratio: {len(original_misspelled) / len(input_text_check_words)}"

# %%
misspelling_df = pd.DataFrame({'misspellings' : ["summary_misspelled" for _ in range(len(summary_misspelled))] + ["input_misspelled" for _ in range(len(original_misspelled))]})

sns.countplot(misspelling_df['misspellings'])

# %% [markdown]
# ### Generate HTML For Visual Proofreading

# %%
table_data = ""
for i, d in bbc_sports['summary_pegasus'].iterrows():
    table_data += f"<tr><td>{d['input_text']}</td><td>{d['summary']}</td></tr>"

# %%
simple_visual_check = f"""
<html>
<body>
<table>
    <tr><th>Original</th><th>Input Text</th></tr>
    {table_data}
</table>
</body>
</html>
"""

# %%
with open('/data/workspace_files/visual_check.html', 'w') as f:
    f.write(simple_visual_check)

# %% [markdown]
# ## Additional Training

# %%
in_df = pd.read_csv("/data/workspace_files/bbc_sports_pegasus_summarized.csv")

# %%
# Train Test Split
train_pct = 0.6
test_pct = 0.2

# %%
in_df = in_df.sample(len(in_df), random_state=20)

# %%
train_sub = int(len(in_df) * train_pct)
test_sub = int(len(in_df) * test_pct) + train_sub
train_df = in_df[0:train_sub]
test_df = in_df[train_sub:test_sub]
val_df = in_df[test_sub:]

# %%
train_texts = list(train_df['contents'])
test_texts = list(test_df['contents'])
val_texts = list(val_df['contents'])

# %%
# This should be the correct summaries
train_decode = list(train_df['summary_pegasus'])
test_decode = list(test_df['summary_pegasus'])
val_decode = list(val_df['summary_pegasus'])

# %%
import transformers
import torch

min_length = 15
max_length = 40

# %%
# Setup model
model_name = 'google/pegasus-xsum'
torch_device = 'cuda' if torch.cuda.is_available() else 'cpu'
tokenizer = transformers.PegasusTokenizer.from_pretrained(model_name)

model = transformers.PegasusForConditionalGeneration.from_pretrained(model_name).to(torch_device)
in_text = [in_df['contents'].iloc[3]]
batch = tokenizer.prepare_seq2seq_batch(in_text, truncation=True, padding='longest').to(torch_device) 

translated = model.generate(min_length=min_length, max_length=max_length, **batch)
tgt_text0 = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text0)

# %%
# Tokenize
train_encodings = tokenizer(train_texts, truncation=True, padding=True)
val_encodings = tokenizer(val_texts, truncation=True, padding=True)
test_encodings = tokenizer(test_texts, truncation=True, padding=True)

train_labels = tokenizer(train_decode, truncation=True, padding=True)
val_labels = tokenizer(val_decode, truncation=True, padding=True)
test_labels = tokenizer(test_decode, truncation=True, padding=True)

# %%
# Setup dataset objects
class Summary_dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels['input_ids'][idx])  # torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.encodings)

# %%
train_dataset = Summary_dataset(train_encodings, train_labels)
val_dataset = Summary_dataset(val_encodings, val_labels)
test_dataset = Summary_dataset(test_encodings, test_labels)

# %% [markdown]
# **Training**

# %%
from transformers import Trainer, TrainingArguments

# %%
training_args = TrainingArguments(
    output_dir='./results',          # output directory
    num_train_epochs=1000,              # total number of training epochs
    per_device_train_batch_size=16,  # batch size per device during training
    per_device_eval_batch_size=64,   # batch size for evaluation
    warmup_steps=500,                # number of warmup steps for learning rate scheduler
    weight_decay=0.01,               # strength of weight decay
    logging_dir='./logs',            # directory for storing logs
    logging_steps=10,
)

# %%
trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args=training_args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=val_dataset             # evaluation dataset
)

# %%
trainer.train()

# %%
# Check results
in_text = [in_df['contents'].iloc[3]]
batch = tokenizer.prepare_seq2seq_batch(in_text, truncation=True, padding='longest').to(torch_device) 

translated = model.generate(min_length=min_length, max_length=max_length, **batch)
tgt_text = tokenizer.batch_decode(translated, skip_special_tokens=True)
print(tgt_text)
